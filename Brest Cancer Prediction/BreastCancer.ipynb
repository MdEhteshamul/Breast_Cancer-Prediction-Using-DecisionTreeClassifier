# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn

# %%
df = pd.read_csv('Breast_cancer_p.csv')

# %%
df
# Out:
#      mean_radius  mean_texture  mean_perimeter  mean_area  mean_smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      diagnosis
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ..         ...
# 564          0
# 565          0
# 566          0
# 567          0
# 568          1
#
# [569 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# mean_radius        0
# mean_texture       0
# mean_perimeter     0
# mean_area          0
# mean_smoothness    0
# diagnosis          0
# dtype: int64

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001DA97DD76C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001DA97E04408>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001DA97E3A788>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001DA97E728C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001DA97EAB988>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001DA97EE2A48>]],
#       dtype=object)

# %%
seaborn.pairplot(df[['mean_radius','mean_texture','mean_perimeter','mean_area','mean_smoothness','diagnosis']])

# %%
df.describe()
# Out:
#        mean_radius  mean_texture  mean_perimeter    mean_area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean_smoothness   diagnosis
# count       569.000000  569.000000
# mean          0.096360    0.627417
# std           0.014064    0.483918
# min           0.052630    0.000000
# 25%           0.086370    0.000000
# 50%           0.095870    1.000000
# 75%           0.105300    1.000000
# max           0.163400    1.000000

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.iloc[:,:-1]

# %%
y = df.iloc[:,5]

# %%
x
# Out:
#      mean_radius  mean_texture  mean_perimeter  mean_area  mean_smoothness
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# [569 rows x 5 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 564    0
# 565    0
# 566    0
# 567    0
# 568    1
# Name: diagnosis, Length: 569, dtype: int64

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=.3)

# %%
xtrain
# Out:
#      mean_radius  mean_texture  mean_perimeter  mean_area  mean_smoothness
# 507        11.06         17.12           71.25      366.5          0.11940
# 443        10.57         18.32           66.82      340.9          0.08142
# 515        11.34         18.61           72.76      391.2          0.10490
# 398        11.06         14.83           70.31      378.2          0.07741
# 77         18.05         16.15          120.20     1006.0          0.10650
# ..           ...           ...             ...        ...              ...
# 244        19.40         23.50          129.10     1155.0          0.10270
# 409        12.27         17.92           78.41      466.1          0.08685
# 552        12.77         29.43           81.35      507.9          0.08276
# 90         14.62         24.02           94.57      662.7          0.08974
# 462        14.40         26.99           92.25      646.1          0.06995
#
# [398 rows x 5 columns]

# %%
ytrain
# Out:
# 507    1
# 443    1
# 515    1
# 398    1
# 77     0
#       ..
# 244    0
# 409    1
# 552    1
# 90     1
# 462    1
# Name: diagnosis, Length: 398, dtype: int64

# %%
xtest
# Out:
#      mean_radius  mean_texture  mean_perimeter  mean_area  mean_smoothness
# 92         13.27         14.76           84.74      551.7          0.07355
# 551        11.13         22.44           71.49      378.4          0.09566
# 202        23.29         26.67          158.90     1685.0          0.11410
# 155        12.25         17.94           78.27      460.3          0.08654
# 364        13.40         16.95           85.48      552.4          0.07937
# ..           ...           ...             ...        ...              ...
# 143        12.90         15.92           83.74      512.2          0.08677
# 303        10.49         18.61           66.86      334.3          0.10680
# 204        12.47         18.60           81.09      481.9          0.09965
# 379        11.08         18.83           73.30      361.6          0.12160
# 73         13.80         15.79           90.43      584.1          0.10070
#
# [171 rows x 5 columns]

# %%
ytest
# Out:
# 92     1
# 551    1
# 202    0
# 155    1
# 364    1
#       ..
# 143    1
# 303    1
# 204    1
# 379    0
# 73     0
# Name: diagnosis, Length: 171, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier()

# %%
dtc.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
dtc.score(xtest,ytest)
# Out:
# 0.8713450292397661
